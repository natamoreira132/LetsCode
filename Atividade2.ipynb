# %% [markdown]
# ## Exercício

# %% [markdown]
# ### Q1
# Quais são os nomes das relações que fazem parte do modelo relacional desse sistema?

# %% [markdown]
# aluno(rg, nome, endereço, data de nascimento, gênero, data de matricula e idade), professores(rg, nome, idade, data de admissão, habilidades, disponibilidade, gênero, data de nascimento e endereço) e cursos(nome, grade e duração)

# %% [markdown]
# ### Q2
# Quais são os esquemas das relações encontradas? Faça uma descrição completa contendo detalhes sobre o domínio dos atributos. Indique quando eles não podem ser nulos.

# %% [markdown]
# esquema aluno
# * atributo nome
# dominio: caracteres que representam o nome de uma pessoa.
# formato: espera-se o nome completo da pessoa (Primeiro nome, nome do meio e sobrenome).
# tipo: este atributo é do tipo texto com o máximo de 60 caractéres.
# * atributo RG
# dominio: conjunto de 8 números que representa um RG
# formato: simples sem somente os números
# tipo: este atributo é do tipo inteiro
# * atributo endereço
# dominio: deve possuir nome da rua, numero, bairro, cidade e CEP
# formato: deve ser (rua, numero, bairro, cidade e CEP)
# tipo: tipo é texto
# * atributo idade
# dominio: representa a idade de uma pessoa
# formato: simples apenas números
# tipo: tipo inteiro
# * atributo gênero
# dominio: representa a como uma pessoa se identifica
# formato: deve ser de forma apreviada exemplo(masculino - masc)
# tipo: tipo é texto
# * atributo data de nascimento
# dominio: representa uma data
# formato: deve ser dd/mm/aaaa
# tipo: tipo é texto
# * atributo data da matricula
# dominio: representa uma data
# formato: deve ser dd/mm/aaaa
# tipo: tipo é texto
#
#
# esquema professores
# * atributo nome
# dominio: caracteres que representam o nome de uma pessoa.
# formato: espera-se o nome completo da pessoa (Primeiro nome, nome do meio e sobrenome).
# tipo: este atributo é do tipo texto com o máximo de 60 caractéres.
# * atributo RG
# dominio: conjunto de 8 números que representa um RG
# formato: simples sem somente os números
# tipo: este atributo é do tipo inteiro
# * atributo endereço
# dominio: deve possuir nome da rua, numero, bairro, cidade e CEP
# formato: deve ser (rua, numero, bairro, cidade e CEP)
# tipo: tipo é texto
# * atributo idade
# dominio: representa a idade de uma pessoa
# formato: simples apenas números
# tipo: tipo inteiro
# * atributo gênero
# dominio: representa a como uma pessoa se identifica
# formato: deve ser de forma apreviada exemplo(masculino - masc)
# tipo: tipo é texto
# * atributo data de nascimento
# dominio: representa uma data
# formato: deve ser dd/mm/aaaa
# tipo: tipo é texto
# * atributo data da admissão
# dominio: representa uma data
# formato: deve ser dd/mm/aaaa
# tipo: tipo é texto
# * atributo habilidade
# dominio: indica as habilidades de uma pessoa
# formato: simples somente a requisito
# tipo: tipo é texto
# * atributo disponibilidade
# dominio: indica a disponibilidade do professor
# tipo: tipo texto
#
# esquema curso
# * duração
# dominio: indica a duração do curso com tipo numerico
# * nome
# dominio: indica o nome do curso com tipo texto
# * grade
# dominio: indica a grade curricular do curso com uma lista tipo texto

# %% [markdown]
# ### Q3
# Quais são as chaves primárias?

# %% [markdown]
# aluno(RG), professor(RG), curso(nome)

# %% [markdown]
# ### Q4
# Represente a integridade referencial entre as relações encontradas.

# %% [markdown]
# ![Diagrama%20ER%20com%20entidades%20coloridas%20%28nota%C3%A7%C3%A3o%20UML%29-2.jpeg](attachment:Diagrama%20ER%20com%20entidades%20coloridas%20%28nota%C3%A7%C3%A3o%20UML%29-2.jpeg)

# %% [markdown]
# ### Q5
# Para cada relação do modelo, indique em qual forma normal ela está e justifique

# %% [markdown]
# todas as relações se emcontram ate a terceira forma evitam atributos multiplos, atibutos não chave dependem totalmente do atributos chave da relação e os atributos não chave não dependem de outros atributos não chave
